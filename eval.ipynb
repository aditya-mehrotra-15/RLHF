# %%
# ==========================================
# STEP 0 — Install Dependencies for Mac GPU
# ==========================================
# !pip install torch transformers peft datasets accelerate tqdm sentencepiece protobuf
# Out:
# Requirement already satisfied: torch in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (2.7.1)
# Requirement already satisfied: transformers in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (4.57.0)
# Requirement already satisfied: peft in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (0.17.1)
# Requirement already satisfied: datasets in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (4.2.0)
# Requirement already satisfied: accelerate in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (1.11.0)
# Requirement already satisfied: tqdm in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (4.67.1)
# Requirement already satisfied: sentencepiece in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (0.2.1)
# Requirement already satisfied: protobuf in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (6.33.0)
# Requirement already satisfied: filelock in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: psutil in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from peft) (7.1.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.0)
# Requirement already satisfied: anyio in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: filelock in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: psutil in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from peft) (7.1.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.0)
# Requirement already satisfied: anyio in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.11.0)
# Requirement already satisfied: certifi in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sahil/miniforge3/envs/amazon/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# ==========================================
# STEP 1 — Imports and Base Setup for Mac GPU
# ==========================================
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoModelForSequenceClassification
from peft import PeftModel
from datasets import load_dataset
from tqdm import tqdm
import zipfile, os

# Detect Mac GPU (Metal Performance Shaders)
if torch.backends.mps.is_available():
    device = "mps"
    print("🎯 Using Metal Performance Shaders (M4 Pro GPU)")
elif torch.cuda.is_available():
    device = "cuda"
    print("🎯 Using CUDA GPU")
else:
    device = "cpu"
    print("⚠️ Using CPU (slower)")

print(f"Device: {device}")
BASE_MODEL = "mistralai/Mistral-7B-v0.3"
# Out:
# 🎯 Using Metal Performance Shaders (M4 Pro GPU)
# Device: mps

# %%
# ==========================================
# STEP 2 — Unzip all models
# ==========================================
def unzip_model(zip_path, target_dir):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(target_dir)
    print(f"✅ Extracted {zip_path} → {target_dir}")

unzip_model("coqa_chatbot_lora.zip", "./sft_lora")
unzip_model("ppo_finetuned_chatbot_2.zip", "./ppo_model")
unzip_model("reward_model.zip", "./reward_model")
# Out:
# ✅ Extracted coqa_chatbot_lora.zip → ./sft_lora
# ✅ Extracted ppo_finetuned_chatbot.zip → ./ppo_model
# ✅ Extracted ppo_finetuned_chatbot.zip → ./ppo_model
# ✅ Extracted reward_model.zip → ./reward_model
# ✅ Extracted reward_model.zip → ./reward_model

# %%
# ==========================================
# STEP 3 — Load Tokenizer
# ==========================================
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, use_fast=False, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token

# %%
# ==========================================
# STEP 4 — Load Models (Optimized for Mac GPU)
# ==========================================

# For Mac GPU: use float16 instead of bfloat16 (not supported on MPS)
# Don't use device_map="auto" with .to(device) — causes conflicts

# --- SFT model (policy before PPO)
sft_base = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL, 
    torch_dtype=torch.float16,
    trust_remote_code=True,
)
sft_model = PeftModel.from_pretrained(sft_base, "./sft_lora", torch_dtype=torch.float16)
sft_model = sft_model.to(device)
sft_model.eval()
print("✅ SFT model loaded")

# --- PPO fine-tuned model (with correct nested path)
ppo_base = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL, 
    torch_dtype=torch.float16,
    trust_remote_code=True,
)

# The PPO adapters are in a nested directory from zip extraction
ppo_adapter_path = "./ppo_model/ppo_finetuned_chatbot"

try:
    ppo_model = PeftModel.from_pretrained(ppo_base, ppo_adapter_path, torch_dtype=torch.float16)
    print(f"✅ PPO model loaded from {ppo_adapter_path}")
except Exception as e:
    print(f"⚠️ PPO model loading failed: {e}")
    print("Using base model as fallback...")
    ppo_model = ppo_base

ppo_model = ppo_model.to(device)
ppo_model.eval()
print("✅ PPO model ready on", device)

# --- Reward model
reward_model = AutoModelForSequenceClassification.from_pretrained(
    "./reward_model", 
    torch_dtype=torch.float16,
    trust_remote_code=True,
)
reward_model = reward_model.to(device)
reward_model.eval()
print("✅ Reward model loaded on", device)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ SFT model loaded
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ PPO model loaded from ./ppo_model/ppo_finetuned_chatbot
# ✅ PPO model ready on mps
# ✅ PPO model ready on mps
# ✅ Reward model loaded on mps
# ✅ Reward model loaded on mps

# %%
# ==========================================
# STEP 5 — Define Evaluation Function (Mac GPU Optimized)
# ==========================================
def compute_avg_reward(model, prompts, reward_model, tokenizer, num_samples=50, max_new_tokens=100):
    total_reward = 0
    count = 0

    for prompt in tqdm(prompts[:num_samples], desc="Evaluating"):
        try:
            # Move inputs to device
            inputs = tokenizer(prompt, return_tensors="pt", truncation=True).to(model.device)
            
            with torch.no_grad():
                outputs = model.generate(
                    **inputs, 
                    max_new_tokens=max_new_tokens, 
                    do_sample=True, 
                    top_p=0.95, 
                    top_k=50
                )
            
            response = tokenizer.decode(outputs[0], skip_special_tokens=True)

            # Combine prompt + response for reward model
            combined = prompt + response
            reward_inp = tokenizer(
                combined, 
                return_tensors="pt", 
                padding=True, 
                truncation=True,
                max_length=reward_model.config.max_position_embeddings
            ).to(reward_model.device)

            with torch.no_grad():
                reward_logits = reward_model(**reward_inp).logits
                reward = reward_logits.squeeze(-1).mean().item()

            total_reward += reward
            count += 1

        except Exception as e:
            print(f"⚠️ Skipping sample due to error: {e}")
            continue

    avg_reward = total_reward / max(1, count)
    return avg_reward

# %%
# ==========================================
# STEP 6 — Prepare Prompts
# ==========================================
# Use a small prompt dataset (Anthropic or CoQA style)
dataset = load_dataset("Anthropic/hh-rlhf", split="train[:1%]")
prompts = [sample["chosen"][:512] for sample in dataset]

# %%
# ==========================================
# STEP 7 — Evaluate Both Models
# ==========================================
print("🔹 Evaluating SFT model...")
sft_avg_reward = compute_avg_reward(sft_model, prompts, reward_model, tokenizer)

print("🔹 Evaluating PPO model...")
ppo_avg_reward = compute_avg_reward(ppo_model, prompts, reward_model, tokenizer)

print("\n================= 📊 Results =================")
print(f"SFT model average reward: {sft_avg_reward:.4f}")
print(f"PPO model average reward: {ppo_avg_reward:.4f}")
print("================================================")

if ppo_avg_reward > sft_avg_reward:
    print("✅ PPO model shows improved alignment!")
else:
    print("⚠️ PPO model reward not higher — consider adjusting KL or reward scaling.")
# Out:
# 🔹 Evaluating SFT model...
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:   2%|▏         | 1/50 [00:17<14:32, 17.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:   2%|▏         | 1/50 [00:17<14:32, 17.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:   4%|▍         | 2/50 [00:26<09:45, 12.19s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:   4%|▍         | 2/50 [00:26<09:45, 12.19s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:   6%|▌         | 3/50 [00:34<08:03, 10.30s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:   6%|▌         | 3/50 [00:34<08:03, 10.30s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:   8%|▊         | 4/50 [00:41<07:08,  9.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:   8%|▊         | 4/50 [00:41<07:08,  9.31s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  10%|█         | 5/50 [00:49<06:29,  8.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  10%|█         | 5/50 [00:49<06:29,  8.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  12%|█▏        | 6/50 [00:57<06:07,  8.35s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  12%|█▏        | 6/50 [00:57<06:07,  8.35s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  14%|█▍        | 7/50 [01:04<05:46,  8.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  14%|█▍        | 7/50 [01:04<05:46,  8.07s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  16%|█▌        | 8/50 [01:12<05:37,  8.04s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  16%|█▌        | 8/50 [01:12<05:37,  8.04s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  18%|█▊        | 9/50 [01:20<05:28,  8.02s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  18%|█▊        | 9/50 [01:20<05:28,  8.02s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  20%|██        | 10/50 [01:28<05:18,  7.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  20%|██        | 10/50 [01:28<05:18,  7.96s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  22%|██▏       | 11/50 [01:35<05:04,  7.80s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  22%|██▏       | 11/50 [01:35<05:04,  7.80s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  24%|██▍       | 12/50 [01:43<04:53,  7.73s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  24%|██▍       | 12/50 [01:43<04:53,  7.73s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  26%|██▌       | 13/50 [01:51<04:48,  7.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  26%|██▌       | 13/50 [01:51<04:48,  7.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  28%|██▊       | 14/50 [01:59<04:39,  7.77s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  28%|██▊       | 14/50 [01:59<04:39,  7.77s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  30%|███       | 15/50 [02:06<04:33,  7.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  30%|███       | 15/50 [02:06<04:33,  7.81s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  32%|███▏      | 16/50 [02:14<04:22,  7.72s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  32%|███▏      | 16/50 [02:14<04:22,  7.72s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  34%|███▍      | 17/50 [02:22<04:14,  7.71s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  34%|███▍      | 17/50 [02:22<04:14,  7.71s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  36%|███▌      | 18/50 [02:29<04:04,  7.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  36%|███▌      | 18/50 [02:29<04:04,  7.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  38%|███▊      | 19/50 [02:37<03:57,  7.67s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  38%|███▊      | 19/50 [02:37<03:57,  7.67s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  40%|████      | 20/50 [02:45<03:49,  7.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  40%|████      | 20/50 [02:45<03:49,  7.65s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  42%|████▏     | 21/50 [02:52<03:41,  7.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  42%|████▏     | 21/50 [02:52<03:41,  7.63s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating:  44%|████▍     | 22/50 [03:00<03:32,  7.60s/it]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Evaluating: